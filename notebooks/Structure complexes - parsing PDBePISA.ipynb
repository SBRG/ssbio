k7r', '3pik', '4k7k', '4k34', '3gp6', '1thq', '1mm4', '1mm5', '1a3a', '2few', '1vrv', '1xqf', '2ns1', '2nop', '2npg', '2npj', '2npk', '3c1j', '1xqe', '2nmr', '2npc', '2npd', '2npe', '2now', '3c1h', '3c1g', '3c1i', '2nuu', '1u7g', '1u7c', '1u77', '1q16', '1y5i', '3egw', '1y4z', '1siw', '3ir5', '1y5l', '1y5n', '3ir7', '3ir6', '1z6f', '1nzo', '1nj4', '1nzu', '1sdn', '5j8x', '3mzf', '3bec', '3mzd', '3beb', '3mze', '1hd8']

# %%
import ssbio.structure.properties.complexes as cplx
# Out:
# /home/nathan/anaconda3/lib/python3.5/site-packages/cobra/solvers/__init__.py:62: UserWarning: No LP solvers found
#   warn("No LP solvers found")

# %%
pisa_xmls = cplx.download_pisa_multimers_xml(pdb_ids=pdbs, outdir='/home/nathan/Downloads/tmp', save_single_xml_files=True)

# %%
pisa_xmls
# Out:
# {'1a3a': '/home/nathan/Downloads/tmp/1a3a_multimers.pisa.xml',
#  '1a3a,1a91,1af6,1aqt,1aty,1bsh,1bsn,1bt9,1bxw,1by3,1by5,1c0v,1c17,1c99,1cyw,1cyx,1d0k,1d0l,1d0m,1ek9,1eq7,1f0x,1fcp,1fep,1fft,1fi1,1fs0,1fw2,1fw3,1fx8,1g90,1gfm,1gfn,1gfo,1gfp,1gfq,1hd8,1hxt,1hxu,1hxx': '/home/nathan/Downloads/tmp/1a3a,1a91,1af6,1aqt,1aty,1bsh,1bsn,1bt9,1bxw,1by3,1by5,1c0v,1c17,1c99,1cyw,1cyx,1d0k,1d0l,1d0m,1ek9,1eq7,1f0x,1fcp,1fep,1fft,1fi1,1fs0,1fw2,1fw3,1fx8,1g90,1gfm,1gfn,1gfo,1gfp,1gfq,1hd8,1hxt,1hxu,1hxx_multimers.pisa.xml',
#  '1a91': '/home/nathan/Downloads/tmp/1a91_multimers.pisa.xml',
#  '1af6': '/home/nathan/Downloads/tmp/1af6_multimers.pisa.xml',
#  '1aqt': '/home/nathan/Downloads/tmp/1aqt_multimers.pisa.xml',
#  '1aty': '/home/nathan/Downloads/tmp/1aty_multimers.pisa.xml',
#  '1bsh': '/home/nathan/Downloads/tmp/1bsh_multimers.pisa.xml',
#  '1bsn': '/home/nathan/Downloads/tmp/1bsn_multimers.pisa.xml',
#  '1bt9': '/home/nathan/Downloads/tmp/1bt9_multimers.pisa.xml',
# ...

# %%
pisa_dict = cplx.parse_pisa_multimers_xml(pisa_xmls['1a3a'], download_structures=True, outdir='/home/nathan/Downloads/tmp')

# %%
pisa_dict['1a3a']
# Out:
# {(1, 1): {'cplx_chains': defaultdict(int, {'B': 1, 'D': 1}),
#   'cplx_composition': 'BD',
#   'cplx_ligands': {},
#   'd_g_diss': -1.7600623954,
#   'd_g_int': -2.9670985543,
#   'pdb_biomol': 2,
#   'stable': False,
#   'structure_file': '/home/nathan/Downloads/tmp/1a3a:1,1.pdb'}}
