# %% [markdown]
# # README
#
# This notebook gives an example of how to run the GEM-PRO pipeline on a **list of gene IDs** in Python 2.
#
# ### Installation
#
# See: https://github.com/nmih/ssbio/blob/master/README.md
# - If something isn't working, make sure to update the repository before you do anything (git pull)

# %%
# Import the GEM-PRO class
from ssbio.pipeline.gempro import GEMPRO

# %%
# Create logger
import logging
logger = logging.getLogger()

############# SET YOUR LOGGING LEVEL HERE #############
# - CRITICAL
#     - Only really important messages shown
# - ERROR
#     - Major errors
# - WARNING
#     - Warnings that don't affect running of the pipeline
# - INFO
#     - Info such as the number of structures mapped per gene
# - DEBUG
#     - Really detailed information that will print out a lot of stuff
logger.setLevel(logging.INFO)
#######################################################

# %% [markdown]
# ## Initialization of the project
#
# Set these three things:
#
# - GEM_NAME
#     - Your project name
# - ROOT_DIR
#     - The directory where the GEM_NAME folder will be created
# - GENES
#     - Your list of gene IDs
#
# A directory will be created in ROOT_DIR named after your GEM_NAME. The folders are:
# ```
#     .
#     ├── data  # where dataframes are stored
#     ├── figures  # where figures are stored
#     ├── model  # where SBML and GEM-PRO models are stored
#     ├── notebooks  # location of any ipython notebooks for analyses
#     ├── sequences  # sequences are stored here, in gene specific folders
#     │   ├── <gene_id1>
#     │   │   └── sequence.fasta
#     │   ├── <gene_id2>
#     │   └── ...
#     └── structures
#         ├── by_gene  # structures are stored here, in gene specific folders
#         │   ├── <gene_id1>
#         │   │   └── 1abc.pdb
#         │   ├── <gene_id2>
#         │   └── ...
#         └── by_complex  # complexes for reactions are stored here (in progress)
# ```

# %%
GEM_NAME = 'py2test'

ROOT_DIR = '/home/nathan/projects_unsynced/'

GENES = ['b0761','b0889','b0995','b1013','b1014','b1040','b1130','b1187','b1221','b1299','b1323']

# %%
# Create the GEM-PRO project
my_gempro = GEMPRO(gem_name=GEM_NAME, root_dir=ROOT_DIR, genes_list=GENES)
# Out:
# INFO:ssbio.pipeline.gempro:Number of genes: 11

# %% [markdown]
# ## Mapping gene ID -> sequence
#
# **You only need to map gene IDs using one service.** However you can try both if some genes don't map in one service and map in another!
#
# ### kegg_mapping_and_metadata
# - kegg_organism_code
#     - See the full list of organisms here: http://www.genome.jp/kegg/catalog/org_list.html
#     - E. coli MG1655 is "eco"
#
# ### uniprot_mapping_and_metadata
# You can try mapping your genes using the actual service here:
# http://www.uniprot.org/uploadlists/
#
# - model_gene_source
#     - Here is a list of the gene IDs that can be mapped to UniProt IDs: http://www.uniprot.org/help/programmatic_access#id_mapping_examples
#     - E. coli b-numbers in this example are of the source "ENSEMBLGENOME_ID"
#
# ### set_representative_sequence
# This function allows you to consolidate sources of ID mapping (currently KEGG and UniProt).
#
# -------------------
#
# ## Saved information:
#
# ### Gene annotations
# Check out the gene annotations saved directly into the gene. These are COBRApy Gene objects!
#     - my_gempro.genes.get_by_id('b1187').annotation
#
# ### DataFrames
# Check out the dataframes to see a summary of results.
#     - my_gempro.df_uniprot_metadata
#     - my_gempro.df_kegg_metadata
#     - my_gempro.df_sequence_mapping  # Summary of the representative sequences

# %%
# Looking at the Gene object - empty for now
example_gene = my_gempro.genes[0]
example_gene.annotation
# Out:
# {'sequence': {'kegg': {'kegg_id': None,
#    'metadata_file': None,
#    'pdbs': [],
#    'seq_file': None,
#    'seq_len': 0,
#    'uniprot_acc': None},
#   'representative': {'kegg_id': None,
#    'metadata_file': None,
#    'pdbs': [],
#    'seq_file': None,
#    'seq_len': 0,
#    'uniprot_acc': None},
#   'uniprot': {}},
#  'structure': {'homology': {},
#   'pdb': OrderedDict(),
#   'representative': {'clean_pdb_file': None,
#    'original_pdb_file': None,
#    'seq_coverage': 0,
#    'structure_id': None}}}

# %%
# UniProt mapping of gene_id -> uniprot_id
my_gempro.uniprot_mapping_and_metadata(model_gene_source='ENSEMBLGENOME_ID')
# Out:
# INFO:root:getUserAgent: Begin
# INFO:root:getUserAgent: user_agent: EBI-Sample-Client/ (services.pyc; Python 2.7.12; Linux) Python-requests/2.9.1
# INFO:root:getUserAgent: End
# 100%|██████████| 11/11 [00:00<00:00, 2010.96it/s]
# INFO:ssbio.pipeline.gempro:Created UniProt metadata dataframe. See the "df_uniprot_metadata" attribute.

# %%
# KEGG mapping of gene ids
my_gempro.kegg_mapping_and_metadata(kegg_organism_code='eco')
# Out:
# 100%|██████████| 11/11 [00:00<00:00, 618.29it/s]
# INFO:ssbio.pipeline.gempro:Created KEGG metadata dataframe. See the "df_kegg_metadata" attribute.

# %%
# Consolidate mappings sources
my_gempro.set_representative_sequence()
# Out:
# INFO:ssbio.pipeline.gempro:Created sequence mapping dataframe. See the "df_sequence_mapping" attribute.

# %%
# Looking at the KEGG dataframe
my_gempro.df_kegg_metadata.head()
# Out:
#     gene uniprot_acc    kegg_id  seq_len                            pdbs  \
# 0  b1323      P07604  eco:b1323      513                          [2JHE]
# 1  b0995      P38684  eco:b0995      230                          [1ZGZ]
# 2  b0761      P0A9G8  eco:b0761      262  [1B9M, 1H9S, 1B9N, 1O7L, 1H9R]
# 3  b1221      P0AF28  eco:b1221      216  [1JE8, 1A04, 1ZG1, 1ZG5, 1RNL]
# 4  b1299      P0A9U6  eco:b1299      185                             NaN
#
#         seq_file   metadata_file
# 0  eco-b1323.faa  eco-b1323.kegg
# 1  eco-b0995.faa  eco-b0995.kegg
# 2  eco-b0761.faa  eco-b0761.kegg
# 3  eco-b1221.faa  eco-b1221.kegg
# 4  eco-b1299.faa  eco-b1299.kegg

# %%
# Looking at information saved per gene
my_gempro.genes.get_by_id('b1187').annotation['sequence']
# Out:
# {'kegg': {'kegg_id': 'eco:b1187',
#   'metadata_file': 'eco-b1187.kegg',
#   'pdbs': ['1HW1', '1H9T', '1HW2', '1H9G', '1E2X'],
#   'seq_file': 'eco-b1187.faa',
#   'seq_len': 239,
#   'uniprot_acc': 'P0A8V6'},
#  'representative': {'kegg_id': ['ecj:JW1176', 'eco:b1187'],
#   'metadata_file': 'P0A8V6.txt',
#   'pdbs': ['1H9T', '1HW2', '1H9G', '1E2X', '1HW1'],
#   'seq_file': 'P0A8V6.fasta',
#   'seq_len': 239,
#   'uniprot_acc': 'P0A8V6'},
#  'uniprot': {'P0A8V6': {'description': ['Fatty acid metabolism regulator protein {ECO:0000255|HAMAP-Rule:MF_00696}'],
#    'entry_version': '2016-10-05',
#    'gene': 'b1187',
#    'gene_name': 'fadR',
#    'kegg_id': ['ecj:JW1176', 'eco:b1187'],
#    'metadata_file': 'P0A8V6.txt',
#    'pdbs': ['1H9T', '1HW2', '1H9G', '1E2X', '1HW1'],
#    'pfam': ['PF07840', 'PF00392'],
#    'refseq': ['NP_415705.1', 'NC_000913.3', 'WP_000234823.1', 'NZ_LN832404.1'],
#    'reviewed': True,
#    'seq_file': 'P0A8V6.fasta',
#    'seq_len': 239,
#    'seq_version': '2007-01-23',
#    'uniprot_acc': 'P0A8V6'}}}

# %% [markdown]
# ## Mapping sequence -> structure
#
# There are two ways to map sequence to structure:
# 1. Simply use the UniProt ID and their automatic mappings to the PDB
# 2. BLAST the sequence to the PDB
#
# ### map_uniprot_to_pdb
# This uses a service from the PDB to return a rank ordered list of PDBs that match a UniProt ID.
# - seq_ident_cutoff (from 0 to 1)
#     - Provide the seq_ident_cutoff as a percentage to filter for structures with only a percent identity above the cutoff.
#     - **Warning:** if you set the seq_ident_cutoff too high you risk filtering out PDBs that do match the sequence, but are just missing large portions of it.
#
# ### blast_seqs_to_pdb
# This will BLAST the representative sequence against the entire PDB, and return significant hits. This will however return hits in other organisms, which may not be ideal.
# - all_genes
#     - Set to True if you want all genes and their sequences BLASTed
#     - Set to False if you only want to BLAST sequences that did not have any PDBs from the function map_uniprot_to_pdb
# - seq_ident_cutoff
#     - Same as above
# - evalue
#     - Significance of BLAST results
#
# -------------------
#
# ## Saved information:
#
# ### Gene annotations
#     - my_gempro.genes.get_by_id('b1187').annotation['structure']['pdb']
#
# ### DataFrames
#     - my_gempro.df_pdb_ranking
#     - my_gempro.df_pdb_blast

# %%
# Mapping using the PDBe best_structures service
my_gempro.map_uniprot_to_pdb(seq_ident_cutoff=.3)
# Out:
# 100%|██████████| 11/11 [00:03<00:00,  2.91it/s]
# INFO:ssbio.pipeline.gempro:Completed UniProt -> best PDB mapping. See the "df_pdb_ranking" attribute.

# %%
# Mapping using BLAST
my_gempro.blast_seqs_to_pdb(all_genes=True, seq_ident_cutoff=.9, evalue=0.00001)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]INFO:ssbio.pipeline.gempro:b1013: Adding 2 PDBs from BLAST results.
# 100%|██████████| 11/11 [00:00<00:00, 151.57it/s]
# INFO:ssbio.pipeline.gempro:Completed sequence --> PDB BLAST. See the "df_pdb_blast" attribute.

# %%
# Looking at the PDB ranking dataframe
my_gempro.df_pdb_ranking.head()
# Out:
#     gene uniprot_acc pdb_id pdb_chain_id experimental_method  resolution  \
# 0  b1323      P07604   2jhe            A   X-ray diffraction         2.3
# 1  b1323      P07604   2jhe            B   X-ray diffraction         2.3
# 2  b1323      P07604   2jhe            C   X-ray diffraction         2.3
# 3  b1323      P07604   2jhe            D   X-ray diffraction         2.3
# 4  b0995      P38684   1zgz            A   X-ray diffraction         1.8
#
#    seq_coverage release_date  taxonomy_id  pdb_start  pdb_end  unp_start  \
# 0          0.37   2008-06-24        83333          1      190          1
# 1          0.37   2008-06-24        83333          1      190          1
# 2          0.37   2008-06-24        83333          1      190          1
# 3          0.37   2008-06-24        83333          1      190          1
# 4          0.53   2005-12-13          562          1      122          1
#
#    unp_end  rank
# 0      190     1
# 1      190     2
# 2      190     3
# 3      190     4
# 4      122     1

# %%
# Looking at the BLAST results
my_gempro.df_pdb_blast.head()
# Out:
#     gene pdb_id pdb_chain_id  resolution release_date  blast_score  \
# 0  b0761   1b9n            A        2.09   2000-03-15       1091.0
# 1  b0761   1b9n            B        2.09   2000-03-15       1091.0
# 2  b0761   1b9m            A        1.75   2000-03-15       1091.0
# 3  b0761   1b9m            B        1.75   2000-03-15       1091.0
# 4  b0761   1o7l            A        2.75   2003-02-20       1089.0
#
#     blast_evalue  seq_coverage  seq_similar  seq_num_coverage  seq_num_similar
# 0  4.797990e-119      0.931298     0.931298               244              244
# 1  4.797990e-119      0.931298     0.931298               244              244
# 2  4.797990e-119      0.931298     0.931298               244              244
# 3  4.797990e-119      0.931298     0.931298               244              244
# 4  9.510390e-119      0.931298     0.931298               244              244

# %%
# Looking at the information saved per gene
my_gempro.genes.get_by_id('b1187').annotation['structure']['pdb']
# Out:
# OrderedDict([(('1hw1', 'A'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'A',
#                'pdb_end': 239,
#                'pdb_id': '1hw1',
#                'pdb_start': 1,
#                'rank': 1,
#                'release_date': '2001-01-24',
#                'resolution': 1.5,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw1', 'B'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'B',
#                'pdb_end': 239,
#                'pdb_id': '1hw1',
#                'pdb_start': 1,
#                'rank': 2,
#                'release_date': '2001-01-24',
#                'resolution': 1.5,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1e2x', 'A'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_id': '1e2x',
#                'pdb_start': 5,
#                'rank': 3,
#                'release_date': '2000-12-03',
#                'resolution': 2,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9g', 'A'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_id': '1h9g',
#                'pdb_start': 5,
#                'rank': 4,
#                'release_date': '2001-03-09',
#                'resolution': 2.1,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9t', 'A'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_id': '1h9t',
#                'pdb_start': 5,
#                'rank': 5,
#                'release_date': '2001-04-04',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9t', 'B'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'B',
#                'pdb_end': 243,
#                'pdb_id': '1h9t',
#                'pdb_start': 5,
#                'rank': 6,
#                'release_date': '2001-04-04',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw2', 'A'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'A',
#                'pdb_end': 239,
#                'pdb_id': '1hw2',
#                'pdb_start': 1,
#                'rank': 7,
#                'release_date': '2001-01-22',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw2', 'B'),
#               {'experimental_method': u'X-ray diffraction',
#                'pdb_chain_id': 'B',
#                'pdb_end': 239,
#                'pdb_id': '1hw2',
#                'pdb_start': 1,
#                'rank': 8,
#                'release_date': '2001-01-22',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1})])

# %% [markdown]
# ## Ranking and downloading structures
#
# ### set_representative_structure
# Rank available structures, run QC/QA, download and clean the final structure
# ### pdb_downloader_and_metadata
# Download all structures per gene. This also adds some additional metadata to the annotation for each PDB.
#
# -------------------
#
# ## Saved information:
#
# ### Gene annotations
#     - my_gempro.genes.get_by_id('b1187').annotation['structure']['representative']
#
# ### DataFrames
#     - my_gempro.df_pdb_metadata

# %%
# Download all mapped PDBs and gather the metadata
my_gempro.pdb_downloader_and_metadata()
# Out:
# 100%|██████████| 11/11 [00:08<00:00,  1.15s/it]
# INFO:ssbio.pipeline.gempro:Created PDB metadata dataframe.

# %%
# Look at the summary of structures
my_gempro.df_pdb_metadata.head()
# Out:
#     gene pdb_id pdb_chain_id     taxonomy_name experimental_method  \
# 0  b1323   2jhe            A  ESCHERICHIA COLI   X-RAY DIFFRACTION
# 1  b1323   2jhe            B  ESCHERICHIA COLI   X-RAY DIFFRACTION
# 2  b1323   2jhe            C  ESCHERICHIA COLI   X-RAY DIFFRACTION
# 3  b1323   2jhe            D  ESCHERICHIA COLI   X-RAY DIFFRACTION
# 4  b0995   1zgz            A  Escherichia coli   X-RAY DIFFRACTION
#
#    resolution  seq_coverage    chemicals  rank release_date  pdb_file  \
# 0         2.3          0.37  AE3;PG4;SO4   1.0   2008-06-24  2jhe.pdb
# 1         2.3          0.37  AE3;PG4;SO4   2.0   2008-06-24  2jhe.pdb
# 2         2.3          0.37  AE3;PG4;SO4   3.0   2008-06-24  2jhe.pdb
# 3         2.3          0.37  AE3;PG4;SO4   4.0   2008-06-24  2jhe.pdb
# 4         1.8          0.53      SO4;GOL   1.0   2005-12-13  1zgz.pdb
#
#       mmcif_header
# 0  2jhe.header.cif
# 1  2jhe.header.cif
# 2  2jhe.header.cif
# 3  2jhe.header.cif
# 4  1zgz.header.cif

# %%
# Looking at information saved per gene
my_gempro.genes.get_by_id('b1187').annotation['structure']['pdb']
# Out:
# OrderedDict([(('1hw1', 'A'),
#               {'chemicals': ['SO4', 'ZN'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1hw1.header.cif',
#                'pdb_chain_id': 'A',
#                'pdb_end': 239,
#                'pdb_file': '1hw1.pdb',
#                'pdb_id': '1hw1',
#                'pdb_start': 1,
#                'rank': 1,
#                'release_date': '2001-01-24',
#                'resolution': 1.5,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'Escherichia coli',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw1', 'B'),
#               {'chemicals': ['SO4', 'ZN'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1hw1.header.cif',
#                'pdb_chain_id': 'B',
#                'pdb_end': 239,
#                'pdb_file': '1hw1.pdb',
#                'pdb_id': '1hw1',
#                'pdb_start': 1,
#                'rank': 2,
#                'release_date': '2001-01-24',
#                'resolution': 1.5,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'Escherichia coli',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1e2x', 'A'),
#               {'chemicals': ['SO4'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1e2x.header.cif',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_file': '1e2x.pdb',
#                'pdb_id': '1e2x',
#                'pdb_start': 5,
#                'rank': 3,
#                'release_date': '2000-12-03',
#                'resolution': 2.0,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'ESCHERICHIA COLI',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9g', 'A'),
#               {'chemicals': ['COA', 'MYR'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1h9g.header.cif',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_file': '1h9g.pdb',
#                'pdb_id': '1h9g',
#                'pdb_start': 5,
#                'rank': 4,
#                'release_date': '2001-03-09',
#                'resolution': 2.1,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'ESCHERICHIA COLI',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9t', 'A'),
#               {'chemicals': ['DC', 'DA', 'DT', 'DG', 'AU', 'CL'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1h9t.header.cif',
#                'pdb_chain_id': 'A',
#                'pdb_end': 243,
#                'pdb_file': '1h9t.pdb',
#                'pdb_id': '1h9t',
#                'pdb_start': 5,
#                'rank': 5,
#                'release_date': '2001-04-04',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'ESCHERICHIA COLI',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1h9t', 'B'),
#               {'chemicals': ['DC', 'DA', 'DT', 'DG', 'AU', 'CL'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1h9t.header.cif',
#                'pdb_chain_id': 'B',
#                'pdb_end': 243,
#                'pdb_file': '1h9t.pdb',
#                'pdb_id': '1h9t',
#                'pdb_start': 5,
#                'rank': 6,
#                'release_date': '2001-04-04',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'ESCHERICHIA COLI',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw2', 'A'),
#               {'chemicals': ['DC', 'DG', 'DA', 'DT', 'MG'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1hw2.header.cif',
#                'pdb_chain_id': 'A',
#                'pdb_end': 239,
#                'pdb_file': '1hw2.pdb',
#                'pdb_id': '1hw2',
#                'pdb_start': 1,
#                'rank': 7,
#                'release_date': '2001-01-22',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'Escherichia coli',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1}),
#              (('1hw2', 'B'),
#               {'chemicals': ['DC', 'DG', 'DA', 'DT', 'MG'],
#                'experimental_method': 'X-RAY DIFFRACTION',
#                'mmcif_header': '1hw2.header.cif',
#                'pdb_chain_id': 'B',
#                'pdb_end': 239,
#                'pdb_file': '1hw2.pdb',
#                'pdb_id': '1hw2',
#                'pdb_start': 1,
#                'rank': 8,
#                'release_date': '2001-01-22',
#                'resolution': 3.25,
#                'seq_coverage': 1,
#                'taxonomy_id': 562,
#                'taxonomy_name': 'Escherichia coli',
#                'uniprot_acc': 'P0A8V6',
#                'unp_end': 239,
#                'unp_start': 1})])

# %%
my_gempro.genes.get_by_id('b1187').annotation
# Out:
# {'sequence': {'kegg': {'kegg_id': 'eco:b1187',
#    'metadata_file': 'eco-b1187.kegg',
#    'pdbs': ['1HW1', '1H9T', '1HW2', '1H9G', '1E2X'],
#    'seq_file': 'eco-b1187.faa',
#    'seq_len': 239,
#    'uniprot_acc': 'P0A8V6'},
#   'representative': {'kegg_id': ['ecj:JW1176', 'eco:b1187'],
#    'metadata_file': 'P0A8V6.txt',
#    'pdbs': ['1H9T', '1HW2', '1H9G', '1E2X', '1HW1'],
#    'seq_file': 'P0A8V6.fasta',
#    'seq_len': 239,
#    'uniprot_acc': 'P0A8V6'},
#   'uniprot': {'P0A8V6': {'description': ['Fatty acid metabolism regulator protein {ECO:0000255|HAMAP-Rule:MF_00696}'],
#     'entry_version': '2016-10-05',
#     'gene': 'b1187',
#     'gene_name': 'fadR',
#     'kegg_id': ['ecj:JW1176', 'eco:b1187'],
#     'metadata_file': 'P0A8V6.txt',
#     'pdbs': ['1H9T', '1HW2', '1H9G', '1E2X', '1HW1'],
#     'pfam': ['PF07840', 'PF00392'],
#     'refseq': ['NP_415705.1',
#      'NC_000913.3',
#      'WP_000234823.1',
#      'NZ_LN832404.1'],
#     'reviewed': True,
#     'seq_file': 'P0A8V6.fasta',
#     'seq_len': 239,
#     'seq_version': '2007-01-23',
#     'uniprot_acc': 'P0A8V6'}}},
#  'structure': {'homology': {},
#   'pdb': OrderedDict([(('1hw1', 'A'),
#                 {'chemicals': ['SO4', 'ZN'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1hw1.header.cif',
#                  'pdb_chain_id': 'A',
#                  'pdb_end': 239,
#                  'pdb_file': '1hw1.pdb',
#                  'pdb_id': '1hw1',
#                  'pdb_start': 1,
#                  'rank': 1,
#                  'release_date': '2001-01-24',
#                  'resolution': 1.5,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'Escherichia coli',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1hw1', 'B'),
#                 {'chemicals': ['SO4', 'ZN'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1hw1.header.cif',
#                  'pdb_chain_id': 'B',
#                  'pdb_end': 239,
#                  'pdb_file': '1hw1.pdb',
#                  'pdb_id': '1hw1',
#                  'pdb_start': 1,
#                  'rank': 2,
#                  'release_date': '2001-01-24',
#                  'resolution': 1.5,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'Escherichia coli',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1e2x', 'A'),
#                 {'chemicals': ['SO4'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1e2x.header.cif',
#                  'pdb_chain_id': 'A',
#                  'pdb_end': 243,
#                  'pdb_file': '1e2x.pdb',
#                  'pdb_id': '1e2x',
#                  'pdb_start': 5,
#                  'rank': 3,
#                  'release_date': '2000-12-03',
#                  'resolution': 2.0,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'ESCHERICHIA COLI',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1h9g', 'A'),
#                 {'chemicals': ['COA', 'MYR'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1h9g.header.cif',
#                  'pdb_chain_id': 'A',
#                  'pdb_end': 243,
#                  'pdb_file': '1h9g.pdb',
#                  'pdb_id': '1h9g',
#                  'pdb_start': 5,
#                  'rank': 4,
#                  'release_date': '2001-03-09',
#                  'resolution': 2.1,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'ESCHERICHIA COLI',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1h9t', 'A'),
#                 {'chemicals': ['DC', 'DA', 'DT', 'DG', 'AU', 'CL'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1h9t.header.cif',
#                  'pdb_chain_id': 'A',
#                  'pdb_end': 243,
#                  'pdb_file': '1h9t.pdb',
#                  'pdb_id': '1h9t',
#                  'pdb_start': 5,
#                  'rank': 5,
#                  'release_date': '2001-04-04',
#                  'resolution': 3.25,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'ESCHERICHIA COLI',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1h9t', 'B'),
#                 {'chemicals': ['DC', 'DA', 'DT', 'DG', 'AU', 'CL'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1h9t.header.cif',
#                  'pdb_chain_id': 'B',
#                  'pdb_end': 243,
#                  'pdb_file': '1h9t.pdb',
#                  'pdb_id': '1h9t',
#                  'pdb_start': 5,
#                  'rank': 6,
#                  'release_date': '2001-04-04',
#                  'resolution': 3.25,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'ESCHERICHIA COLI',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1hw2', 'A'),
#                 {'chemicals': ['DC', 'DG', 'DA', 'DT', 'MG'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1hw2.header.cif',
#                  'pdb_chain_id': 'A',
#                  'pdb_end': 239,
#                  'pdb_file': '1hw2.pdb',
#                  'pdb_id': '1hw2',
#                  'pdb_start': 1,
#                  'rank': 7,
#                  'release_date': '2001-01-22',
#                  'resolution': 3.25,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'Escherichia coli',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1}),
#                (('1hw2', 'B'),
#                 {'chemicals': ['DC', 'DG', 'DA', 'DT', 'MG'],
#                  'experimental_method': 'X-RAY DIFFRACTION',
#                  'mmcif_header': '1hw2.header.cif',
#                  'pdb_chain_id': 'B',
#                  'pdb_end': 239,
#                  'pdb_file': '1hw2.pdb',
#                  'pdb_id': '1hw2',
#                  'pdb_start': 1,
#                  'rank': 8,
#                  'release_date': '2001-01-22',
#                  'resolution': 3.25,
#                  'seq_coverage': 1,
#                  'taxonomy_id': 562,
#                  'taxonomy_name': 'Escherichia coli',
#                  'uniprot_acc': 'P0A8V6',
#                  'unp_end': 239,
#                  'unp_start': 1})]),
#   'representative': {'clean_pdb_file': None,
#    'original_pdb_file': None,
#    'seq_coverage': 0,
#    'structure_id': None}}}
